# %%
#!pip install zarr
#!pip install vizarr
#!pip install numpy

# %%
import zarr
import vizarr
import numpy as np
import qim3d

# %%
#zarr_path = "../PyHPC/ome_array_pyramid_inference.zarr"
zarr_path = "/work3/s173944/Python/courses/PyHPC/data/MRI_images/0190_CT.zarr"
store = zarr.open(zarr_path, mode='r')
print(store.tree())
# Out:
# /
#  └── volume
#      ├── 0 (512, 512, 512) float32
#      ├── 1 (256, 256, 256) float32
#      └── 2 (128, 128, 128) float32

# %%
# Explore chunks
qim3d.viz.chunks(zarr_path + "/volume")
# Out:
# VBox(children=(HTML(value='<h2>Chunk Explorer</h2>'), HBox(children=(VBox(children=(Dropdown(description='OME-…

# %%
# viewer = vizarr.Viewer()
# viewer.add_image(source=store, name="volume")
# viewer
# Out:
# Viewer()
